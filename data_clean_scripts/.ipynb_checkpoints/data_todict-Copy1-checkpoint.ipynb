# %%
import pandas as pd
import pprint as pp

df = pd.read_csv('../data/AllGunShootings.csv') 
dfList = df['participant_status'].fillna('')

### Set string from csv to dict datastructure, BEWARE: all keys are of 
### type string
def to_dict(string_dict):
    
    # set start values
    goal = {}
    val = ''
    len_string_dict = len(string_dict)
    key_switcher = True
    
    # Iterate over string indices
    for i in range(len_string_dict):
        # look for token
        if string_dict[i] == ':' and key_switcher == True:
            key_switcher = False
        # look for seperator
        elif (string_dict[i] == '|' and key_switcher == False):
            key_switcher = True
            goal[key] = val
            val = ''
        # look for key
        elif key_switcher == True and \
        not (string_dict[i] == ':' or string_dict[i] == '|'):
            key = int(string_dict[i])
        # look for value
        elif not (string_dict[i] == ':' or string_dict[i]) == '|':
            val += string_dict[i]
            
    # only add to dict if string is not empty
    if len_string_dict > 0:
        goal[key] = val
        
    return goal

# get all dicts in List
[to_dict(x) for x in dfList]
# Out:
# [{0: ':Arrested', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured, Unharmed, Arrested',
#   1: ':Unharmed, Arrested',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Killed', 3: ':Killed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Killed',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Killed',
#   4: ':Injured, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured', 4: ':Killed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Killed, Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Killed',
#   5: ':Killed',
#   6: ':Killed'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Unharmed, Arrested',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Killed',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Killed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed',
#   6: ':Unharmed',
#   7: ':Injured',
#   8: ':Injured',
#   9: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested',
#   7: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Killed',
#   5: ':Killed',
#   6: ':Killed',
#   7: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Unharmed',
#   8: ':Unharmed',
#   9: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Injured, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Killed',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Killed', 4: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested',
#   7: ':Unharmed, Arrested',
#   8: ':Unharmed, Arrested',
#   9: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Killed',
#   5: ':Injured',
#   6: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed',
#   5: ':Unharmed',
#   6: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Killed, Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured, Unharmed, Arrested'},
#  {0: ':Unharmed, Arrested',
#   1: ':Unharmed, Arrested',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Injured',
#   9: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Killed', 1: ':Arrested', 2: ':Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Killed', 4: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Killed', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured, Unharmed',
#   4: ':Unharmed',
#   5: ':Injured, Unharmed',
#   6: ':Unharmed',
#   7: ':Unharmed',
#   8: ':Injured, Unharmed',
#   9: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Unharmed',
#   8: ':Unharmed',
#   9: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Killed',
#   5: ':Injured',
#   6: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed',
#   6: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested',
#   7: ':Unharmed, Arrested',
#   8: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Unharmed',
#   7: ':Unharmed, Arrested',
#   8: ':Unharmed, Arrested',
#   9: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed, Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Injured',
#   9: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Unharmed, Arrested',
#   1: ':Unharmed, Arrested',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Injured',
#   5: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Injured',
#   9: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed',
#   5: ':Unharmed',
#   6: ':Unharmed',
#   7: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Killed',
#   5: ':Killed',
#   6: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed',
#   6: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Killed',
#   5: ':Killed',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested',
#   7: ':Unharmed, Arrested',
#   8: ':Unharmed, Arrested',
#   9: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Killed', 4: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested',
#   7: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Killed',
#   3: ':Killed',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Killed',
#   6: ':Killed',
#   7: ':Killed',
#   9: ':Killed'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Unharmed, Arrested',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed',
#   7: ':Unharmed, Arrested',
#   8: ':Unharmed, Arrested',
#   9: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Killed', 4: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested',
#   7: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Injured',
#   9: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Killed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Killed', 4: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   6: ':Injured',
#   7: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 3: ':Killed', 4: ':Killed', 5: ':Killed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Killed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Injured',
#   9: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Unharmed, Arrested',
#   9: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested',
#   5: ':Unharmed, Arrested',
#   6: ':Unharmed, Arrested',
#   7: ':Unharmed, Arrested',
#   8: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Injured', 4: ':Killed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Arrested'},
#  {0: ':Injured', 1: ':Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Killed', 4: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Unharmed',
#   8: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Arrested',
#   6: ':Arrested',
#   7: ':Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Arrested'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Arrested'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Unharmed, Arrested'},
#  {0: ':Killed'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed', 3: ':Injured', 4: ':Injured'},
#  {0: ':Injured',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Killed',
#   4: ':Injured',
#   5: ':Killed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Killed',
#   6: ':Injured',
#   7: ':Injured',
#   8: ':Unharmed, Arrested',
#   9: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Killed',
#   3: ':Injured',
#   4: ':Unharmed',
#   5: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Injured',
#   4: ':Injured',
#   5: ':Injured',
#   6: ':Unharmed',
#   7: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Unharmed'},
#  {},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Unharmed'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed, Arrested', 1: ':Unharmed, Arrested'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Unharmed',
#   4: ':Unharmed',
#   5: ':Unharmed',
#   6: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed, Arrested',
#   1: ':Unharmed, Arrested',
#   2: ':Unharmed, Arrested',
#   3: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Killed', 2: ':Killed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed, Arrested'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Injured',
#   3: ':Unharmed',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Unharmed, Arrested'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {},
#  {0: ':Unharmed'},
#  {},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Injured'},
#  {},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured, Arrested'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed, Arrested'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed, Arrested'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Killed', 3: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {},
#  {0: ':Injured', 1: ':Unharmed'},
#  {},
#  {0: ':Killed', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed, Arrested'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed'},
#  {},
#  {0: ':Killed', 1: ':Killed'},
#  {},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed, Arrested'},
#  {0: ':Unharmed'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {0: ':Injured', 1: ':Injured', 2: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Injured', 2: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed'},
#  {1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured'},
#  {},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Killed', 1: ':Killed'},
#  {},
#  {0: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {1: ':Unharmed'},
#  {0: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Unharmed, Arrested',
#   2: ':Unharmed, Arrested',
#   3: ':Unharmed, Arrested'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {},
#  {},
#  {},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed', 3: ':Killed'},
#  {0: ':Injured', 1: ':Killed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed, Arrested'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured'},
#  {},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Injured'},
#  {},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed'},
#  {},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {},
#  {0: ':Killed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Killed', 1: ':Killed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {},
#  {},
#  {},
#  {},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Killed',
#   1: ':Killed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Injured', 2: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Killed'},
#  {0: ':Killed', 1: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed, Arrested'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Killed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 3: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {},
#  {0: ':Killed'},
#  {},
#  {0: ':Injured', 1: ':Killed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {},
#  {0: ':Killed', 1: ':Injured', 2: ':Unharmed', 3: ':Unharmed', 4: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed, Arrested'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured, Arrested'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Killed'},
#  {0: ':Killed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Killed',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {},
#  {0: ':Killed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed'},
#  {},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Unharmed',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Killed'},
#  {},
#  {0: ':Killed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured', 3: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Unharmed, Arrested', 2: ':Unharmed, Arrested'},
#  {0: ':Injured', 1: ':Unharmed, Arrested'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {1: ':Killed'},
#  {},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Killed'},
#  {},
#  {1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed'},
#  {0: ':Killed'},
#  {},
#  {0: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Unharmed', 4: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed',
#   5: ':Unharmed',
#   6: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {},
#  {0: ':Injured',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed'},
#  {0: ':Injured', 1: ':Killed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Injured'},
#  {},
#  {0: ':Unharmed, Arrested'},
#  {},
#  {0: ':Killed', 1: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Injured', 2: ':Killed'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {},
#  {},
#  {0: ':Killed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Injured', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed'},
#  {},
#  {0: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured',
#   1: ':Injured',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed',
#   5: ':Injured',
#   6: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Killed'},
#  {0: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured', 2: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Injured'},
#  {},
#  {0: ':Injured', 1: ':Injured'},
#  {},
#  {0: ':Injured'},
#  {},
#  {0: ':Killed'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Killed', 2: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Injured'},
#  {0: ':Unharmed',
#   1: ':Unharmed',
#   2: ':Unharmed',
#   3: ':Unharmed',
#   4: ':Unharmed',
#   5: ':Unharmed'},
#  {0: ':Killed', 1: ':Injured', 2: ':Injured', 3: ':Injured', 4: ':Unharmed'},
#  {},
#  {},
#  {},
#  {0: ':Unharmed', 1: ':Injured'},
#  {0: ':Killed', 1: ':Unharmed, Arrested'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed', 3: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Unharmed'},
#  {0: ':Injured', 1: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Killed'},
#  {0: ':Unharmed', 1: ':Unharmed'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Injured'},
#  {0: ':Unharmed', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed', 2: ':Unharmed'},
#  {0: ':Killed'},
#  {},
#  {0: ':Injured'},
#  {0: ':Injured', 1: ':Unharmed'},
#  {0: ':Injured', 1: ':Unharmed'},
#  ...]
