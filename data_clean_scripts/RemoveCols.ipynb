# %%
import pandas as pd

# read data
df = pd.read_csv('../data/AllGunShootings.csv')
df.drop([df.columns[0], 'congressional_district', 'address', 'incident_url', 'source_url', 'incident_url_fields_missing' 
        ,'gun_stolen', 'gun_type', 'location_description', 'notes', 'participant_name', 'sources' 
        ,'state_house_district', 'state_senate_district'], axis=1, inplace=True)
df.head()
#file_name= 'AllGunShootings.csv'
#df.to_csv(file_name)

# %%
df.head()
# Out:
#    incident_id        date           state  state_population  state_gun_laws  \
# 0       461105  2013-01-01    Pennsylvania          12805537             2.0
# 1       460726  2013-01-01      California          39536653             6.0
# 2       478855  2013-01-01            Ohio          11658609             0.5
# 3       478925  2013-01-05        Colorado           5607154             3.5
# 4       478959  2013-01-07  North Carolina          10273419             2.5
#
#   city_or_county  n_killed  n_injured  \
# 0     Mckeesport         0          4
# 1      Hawthorne         1          3
# 2         Lorain         1          3
# 3         Aurora         4          0
# 4     Greensboro         2          2
#
#                             incident_characteristics  latitude  longitude  \
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467   -79.8559
# 1  Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090  -118.3330
# ...
