# %%
import pandas as pd

df = pd.read_csv('data/AllGunShootings.csv')
df = df.set_index('incident_id')
df.head()
# Out:
#                    date           state city_or_county  n_killed  n_injured  \
# incident_id
# 461105       2013-01-01    Pennsylvania     Mckeesport         0          4
# 460726       2013-01-01      California      Hawthorne         1          3
# 478855       2013-01-01            Ohio         Lorain         1          3
# 478925       2013-01-05        Colorado         Aurora         4          0
# 478959       2013-01-07  North Carolina     Greensboro         2          2
#
#                                       incident_characteristics  latitude  \
# incident_id
# 461105       Shot - Wounded/Injured||Mass Shooting (4+ vict...   40.3467
# 460726       Shot - Wounded/Injured||Shot - Dead (murder, a...   33.9090
# 478855       Shot - Wounded/Injured||Shot - Dead (murder, a...   41.4455
# 478925       Shot - Dead (murder, accidental, suicide)||Off...   39.6518
# 478959       Shot - Wounded/Injured||Shot - Dead (murder, a...   36.1140
#
# ...
