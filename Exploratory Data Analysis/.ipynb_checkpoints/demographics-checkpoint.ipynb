# %%
import pandas as pd
import pandas as pd
import pprint as pp
import matplotlib.pyplot as plt
import plotly
import plotly.plotly as py
import cufflinks as cf
import pandas as pd
import numpy as np
import plotly.graph_objs as go

plotly.tools.set_credentials_file(username='BramBakker', api_key='6GXtQ5dT304fZa9hNqTq')



df = pd.read_csv('../data/AllGunShootings.csv') 
dfList = df['participant_age_group'].fillna('')
dfList2 = df['participant_type'].fillna('')
dfList3 = df['incident_characteristics'].fillna('')
dfList4 = df['participant_age'].fillna('')
dfList5 = df['participant_gender'].fillna('')


# get all dicts in Lists
ages=[to_dict(x) for x in dfList4]
age=[to_dict(x) for x in dfList]
part=[to_dict(x) for x in dfList2]
gender=[to_dict(x) for x in dfList5]

#counters

male_domestic=0
female_domestic=0
home_invasion=0
suicide=0
accidental=0
teen_suspect=0
male_suspect=0
female_suspect=0
mass=0
domestic=0
teen_mass=0
child_suspect=0
adult_suspect=0
adult_mass=0
child_mass=0
total=len(dfList3)
# iterate over the lists and compare the values of each dict to match the teens to subject/suspects
# then check whether the corresponding shooting was a mass shooting
for index in range(len(age)):
    if 'Mass Shooting' in dfList3[index]:
        mass += 1
    if 'Home' in dfList3[index]:
        home_invasion += 1
    if 'Suicide' in dfList3[index]:
        suicide += 1
    if 'Accidental' in dfList3[index]:
        accidental+=1
    if 'Domestic' in dfList3[index]:
        domestic +=1
    for key, value in age[index].items():
        if 'Subject-Suspect' in part[index][key]:
            if 'Adult 18+' in age[index][key]:
                adult_suspect +=1
                if 'Mass' in dfList3[index]:
                    adult_mass += 1
            if 'Teen 12-17' in age[index][key]:      
                teen_suspect += 1
                if 'Mass' in dfList3[index]:
                    teen_mass += 1
            if 'Child 0-11' in age[index][key]:
                child_suspect += 1

for index in range(len(gender)):
    for key, value in gender[index].items():
        if 'Male' in gender[index][key]:
            if 'Subject-Suspect' in part[index][key]:
                male_suspect +=1
                if 'Domestic' in dfList3[index]:
                    male_domestic +=1 
                
        if 'Female' in gender[index][key]:
            if 'Subject-Suspect' in part[index][key]:
                female_suspect +=1
                if 'Domestic' in dfList3[index]:
                    female_domestic +=1

#
w=male_domestic+female_domestic
percent_male_domestic=round(((male_domestic/w)*100),2)          
percent_female_domestic=round(((female_domestic/w)*100),2)          
print(percent_female_domestic)

x=male_suspect+female_suspect
percent_male=round(((male_suspect/x)*100),2)
percent_female=round(((female_suspect/x)*100),2)

y=adult_suspect+teen_suspect+child_suspect
percent_adult=round(((adult_suspect/y)*100),2)
percent_teen=round(((teen_suspect/y)*100),2)
percent_child=round(((child_suspect/y)*100),2)

z=adult_mass+teen_mass+child_mass
percent_adult_mass=round(((adult_mass/z)*100),2)
percent_teen_mass=round(((teen_mass/z)*100),2)
percent_child_mass=round(((child_mass/z)*100),2)



percent_accidental=round(((accidental/total)*100),2)
percent_home_invasion=round(((home_invasion/total)*100),2)
percent_other=round((((total-mass-suicide-accidental-home_invasion-domestic)/total)*100),2)
percent_suicide=round(((suicide/total)*100),2)
percent_domestic=round(((domestic/total)*100),2)
percent_mass=round(((mass/total)*100),2)


trace1 = go.Bar(
    x=[percent_child, percent_child_mass],
    y=['age', 'age mass'],
    marker=dict(
    color = ['rgb(255,152,152)', 'rgb(255,152,152)']),
    name='children 0-11',
    orientation='h'
)
trace2 = go.Bar(
    x=[percent_teen, percent_teen_mass],
    y=['age', 'age mass'],
    marker=dict(
    color = ['rgb(255,102,102)', 'rgb(255,102,102)']),
    name='teens 12-17',
    orientation='h'
)
trace3 = go.Bar(
    x=[percent_adult, percent_adult_mass],
    y=['age', 'age mass'],
    marker=dict(
    color = ['rgb(230,70,70)', 'rgb(255,70,70)']),
    name='adults 18+',
    orientation='h'
)
trace4 = go.Bar(
    x=[percent_female, percent_female_domestic],
    y=['gender', 'gender domestic violence'],
    marker=dict(
    color = ['rgb(255,78,102)', 'rgb(255,78,102)']),
    name='female',
    orientation='h'
)
trace5 = go.Bar(
    x=[percent_male, percent_male_domestic],
    y=['gender', 'gender domestic violence'],
    marker=dict(
    color = ['rgb(255,128,152)', 'rgb(255,128,152)']),
    name='male',
    orientation='h'
)
data = [trace1, trace2, trace3, trace4, trace5]
layout = go.Layout(
    title='percentage shooting demographics',
    barmode='stack',
    orientation='h'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar-demographics')       
        
#comparing numbers
print(female_domestic)
print(percent_male)
print(percent_female)
print(male_suspect)
print(female_suspect)
print(child_suspect)
print(adult_suspect)
print(child_mass)
print(adult_mass)
print('shootings with teens as Subject-Suspects: %d'% teen_suspect)
print('total mass shootings: %d'% mass)
print('mass shootings by teens: %d'% teen_mass)
# Out:
# 13.7
# 1430
# 93.46
# 6.54
# 170164
# 11917
# 591
# 153572
# 0
# 1201
# shootings with teens as Subject-Suspects: 13085
# total mass shootings: 1637
# mass shootings by teens: 96

# %%
df = pd.read_csv('../data/AllGunShootings.csv') 
### Set string from csv to dict datastructure
dfList5 = df['participant_gender'].fillna('')

def to_dict(string_dict):
    
    # set start values
    goal = {}
    val = ''
    len_string_dict = len(string_dict)
    key_switcher = True
    
    # Iterate over string indices
    for i in range(len_string_dict):
        # look for token
        if string_dict[i] == ':' and key_switcher == True:
            key_switcher = False
        # look for seperator
        elif (string_dict[i] == '|' and key_switcher == False):
            key_switcher = True
            goal[key] = val
            val = ''
        # look for key
        elif key_switcher == True and \
        not (string_dict[i] == ':' or string_dict[i] == '|'):
            key = int(string_dict[i])
        # look for value
        elif not(string_dict[i] == ':' or string_dict[i] == '|'):
            val += string_dict[i]
            
    # only add to dict if string is not empty
    if len_string_dict > 0:
        goal[key] = val
        
    return goal
[to_dict(x) for x in dfList5]
# Out:
# [{0: 'Male', 1: 'Male', 3: 'Male', 4: 'Female'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Female', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Female', 4: 'Female', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Female',
#   1: 'Female',
#   2: 'Female',
#   3: 'Female',
#   4: 'Female',
#   5: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 4: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male',
#   1: 'Female',
#   2: 'Female',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Female'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Male', 5: 'Male'},
#  {0: 'Female', 4: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Female',
#   7: 'Female',
#   8: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female'},
#  {3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {0: 'Female',
#   1: 'Female',
#   2: 'Female',
#   3: 'Female',
#   4: 'Female',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male',
#   8: 'Male',
#   9: 'Female'},
#  {0: 'Male', 1: 'Male', 4: 'Male', 5: 'Male', 6: 'Male', 7: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 4: 'Male', 5: 'Male', 6: 'Male', 7: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {},
#  {0: 'Male', 1: 'Female', 2: 'Female'},
#  {},
#  {0: 'Female',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male',
#   8: 'Male',
#   9: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Male', 5: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Female',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male',
#   1: 'Female',
#   2: 'Female',
#   3: 'Female',
#   4: 'Female',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male',
#   8: 'Male',
#   9: 'Male'},
#  {0: 'Female',
#   1: 'Female',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Female',
#   6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Female', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 3: 'Male', 4: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 3: 'Female', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Female'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Female',
#   3: 'Female',
#   4: 'Female',
#   5: 'Female',
#   6: 'Female',
#   7: 'Male',
#   8: 'Female',
#   9: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Female', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {2: 'Male', 3: 'Female', 4: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {},
#  {3: 'Male', 4: 'Male', 5: 'Male', 6: 'Male', 8: 'Male', 9: 'Male'},
#  {0: 'Female',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male',
#   8: 'Male',
#   9: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Female',
#   4: 'Female',
#   5: 'Female',
#   6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Female',
#   3: 'Male',
#   4: 'Female',
#   5: 'Female',
#   6: 'Male'},
#  {0: 'Female', 1: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Female',
#   1: 'Female',
#   3: 'Female',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Male'},
#  {6: 'Male', 7: 'Male', 8: 'Male', 9: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 4: 'Male'},
#  {0: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 9: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Female',
#   5: 'Female',
#   6: 'Female',
#   7: 'Female',
#   9: 'Female'},
#  {},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   3: 'Female',
#   4: 'Female',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {4: 'Female'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Female', 3: 'Female'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Female', 4: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 5: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Female',
#   4: 'Female',
#   5: 'Male',
#   6: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Male', 5: 'Male'},
#  {},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Female', 4: 'Male', 5: 'Male'},
#  {0: 'Female', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {},
#  {0: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male',
#   1: 'Female',
#   2: 'Male',
#   3: 'Male',
#   4: 'Female',
#   5: 'Female',
#   6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Female',
#   7: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Female',
#   6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Male'},
#  {0: 'Female',
#   1: 'Female',
#   2: 'Male',
#   3: 'Male',
#   4: 'Female',
#   6: 'Male',
#   7: 'Male',
#   8: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Female', 3: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female', 4: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male',
#   8: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Female', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Female', 5: 'Female'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {4: 'Male'},
#  {},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Female', 5: 'Female'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Female',
#   4: 'Female',
#   5: 'Male',
#   6: 'Female',
#   7: 'Male',
#   8: 'Male',
#   9: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 5: 'Male'},
#  {},
#  {},
#  {0: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male',
#   8: 'Male',
#   9: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Female'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 6: 'Male', 7: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Female', 3: 'Female'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 3: 'Female', 4: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male',
#   8: 'Male',
#   9: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 8: 'Male', 9: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Female',
#   1: 'Female',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   7: 'Male',
#   8: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {0: 'Male', 1: 'Female', 3: 'Male'},
#  {},
#  {0: 'Female', 1: 'Female', 2: 'Female', 3: 'Female'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Female', 3: 'Male', 4: 'Female', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 8: 'Male'},
#  {0: 'Female',
#   1: 'Male',
#   2: 'Male',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male',
#   8: 'Male',
#   9: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 5: 'Female'},
#  {0: 'Male'},
#  {0: 'Female'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female'},
#  {1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Female'},
#  {},
#  {},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male',
#   1: 'Male',
#   2: 'Female',
#   3: 'Male',
#   4: 'Male',
#   5: 'Male',
#   6: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Female'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female'},
#  {},
#  {2: 'Male'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {2: 'Male'},
#  {0: 'Female'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {},
#  {0: 'Female', 1: 'Male'},
#  {3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male', 3: 'Female'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {},
#  {0: 'Male', 1: 'Female', 2: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {1: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female', 1: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Female', 2: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male'},
#  {1: 'Male', 2: 'Male'},
#  {1: 'Male'},
#  {0: 'Female', 2: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {},
#  {0: 'Male'},
#  {},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Female'},
#  {},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female'},
#  {1: 'Male'},
#  {0: 'Female', 1: 'Female'},
#  {0: 'Male'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Female'},
#  {0: 'Female', 1: 'Male'},
#  {},
#  {1: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Female', 3: 'Female', 4: 'Male', 5: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Female', 4: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female', 3: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {},
#  {},
#  {},
#  {},
#  {0: 'Male'},
#  {2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {4: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male'},
#  {2: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Female', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Female', 3: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {1: 'Male'},
#  {0: 'Female', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male'},
#  {1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Female'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {1: 'Male', 2: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male'},
#  {1: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Female', 2: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {1: 'Male', 2: 'Male'},
#  {4: 'Male', 5: 'Male', 6: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {1: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Male'},
#  {1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female'},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {},
#  {},
#  {},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {0: 'Female', 1: 'Female'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Male', 5: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Female', 3: 'Female', 4: 'Male'},
#  {},
#  {},
#  {},
#  {0: 'Female', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male'},
#  {1: 'Male'},
#  {},
#  {1: 'Male'},
#  {1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Female'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male', 1: 'Male', 2: 'Male'},
#  {0: 'Male'},
#  {},
#  {0: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  {0: 'Male', 1: 'Male'},
#  ...]
